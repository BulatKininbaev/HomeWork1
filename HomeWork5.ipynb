# %% [markdown]
# Задание 1
# $g(x) = 2^x + 1 \quad
# g(g(2)) = 11
# $

# %% [markdown]
# Задание 2.
# посчитайте матрицу $D = A^T C - 2A^T B^T \$.

# %% [markdown]
# $
# A = \begin{pmatrix}
# 2 & -4 \\
# 3 & 5 \\
# -1 & 0
# \end{pmatrix}, \quad
# B = \begin{pmatrix}
# 1 & 2 & 7 \\
# -3 & -4 & 0 \\
# 5 & 2 & 1
# \end{pmatrix}, \quad
# C = \begin{pmatrix}
# 6 & -3 & 9 \\
# 4 & -5 & 2 \\
# 8 & 1 & 5
# \end{pmatrix}.
# $

# %% [markdown]
# $D = A^T C - 2A^T B^T = A^T(C-2B^T) \$

# %% [markdown]
# $
# A^T = \begin{pmatrix}
# 2 & 3 & -1\\
# -4 & 5 & 0
# \end{pmatrix}, \quad
# B^T = \begin{pmatrix}
# 1 & -3 & 5 \\
# 2 & -4 & 2 \\
# 7 & 0 & 1
# \end{pmatrix} .
# $

# %% [markdown]
# $ C-2B^T = \begin{pmatrix}
# 6 & -3 & 9 \\
# 4 & -5 & 2 \\
# 8 & 1 & 5
# \end{pmatrix}  -
# 2 \cdot \begin{pmatrix}
# 1 & -3 & 5 \\
# 2 & -4 & 2 \\
# 7 & 0 & 1
# \end{pmatrix} =
# \begin{pmatrix}
# 6 & -3 & 9 \\
# 4 & -5 & 2 \\
# 8 & 1 & 5
# \end{pmatrix}  -
# \begin{pmatrix}
# 2 & -6 & 10 \\
# 4 & -8 & 4 \\
# 14 & 0 & 2
# \end{pmatrix} =
# \begin{pmatrix}
# 4 & 3 & -1 \\
# 0 & 3 & -2 \\
# -6 & 1 & 3
# \end{pmatrix}
# $

# %% [markdown]
# $ A^T(C-2B^T) = \begin{pmatrix}
# 2 & 3 & -1\\
# -4 & 5 & 0
# \end{pmatrix} \cdot
# \begin{pmatrix}
# 4 & 3 & -1 \\
# 0 & 3 & -2 \\
# -6 & 1 & 3
# \end{pmatrix} =
#  \begin{pmatrix}
# 14 & 14 & -11\\
# -16 & 3 & -6
# \end{pmatrix}
# $

# %% [markdown]
# $D = A^T C - 2A^T B^T  = \begin{pmatrix}
# 14 & 14 & -11\\
# -16 & 3 & -6
# \end{pmatrix} $

# %% [markdown]
# Задание 3
#
# Дано выражение:
#
# $$
# 3 \cdot \begin{pmatrix}
# x & 2 & 3 \\
# -1 & y & 4
# \end{pmatrix}
# + 2 \cdot \begin{pmatrix}
# 1 & 2 & -5 \\
# 2 & -6 & z
# \end{pmatrix}
# = \begin{pmatrix}
# 8 & v & -1 \\
# 1 & 6 & 4
# \end{pmatrix}.
# $$
#
# Найдите значения $(x, y, z)$ и $v$, при которых выражение верно.

# %% [markdown]
# $$
#  \begin{pmatrix}
# 3x & 6 & 9 \\
# -3 & 3y & 12
# \end{pmatrix}
# + \begin{pmatrix}
# 2 & 4 & -10 \\
# 4 & -12 & 2z
# \end{pmatrix}
# = \begin{pmatrix}
# 8 & v & -1 \\
# 1 & 6 & 4
# \end{pmatrix}.
# $$

# %% [markdown]
# $
# 3x+2 = 8;\quad 3x=6; \quad x=2;
# \quad 3y-12 = 6; \quad y-4 = 2; \quad y=6;
# \quad v=6;
# \quad 12+2z=4;\quad 2z=4-12; \quad 2z=-8; \quad z=-4;
# $

# %% [markdown]
# Задание 4
#
#  координатной плоскости отмечено 3 точки:
#
# <img src="https://github.com/dmi3eva/resources/blob/main/2026-04-27_OLS-home.png?raw=true" width="500">
#
# **Цель:**
#
# Найти прямую, проходящую через (0, 0), для которой минимальна:
#
# 3) Сумма отклонений от данных точек по `у`
#
# 4) Сумма квадратов отклонений от данных точек по `у`

# %% [markdown]
# Мне нужно найти функцию
# $
#   y = k \dot x \quad формула \quad отклонений \quad \Delta=|k \dot x - y| \quad минимальная \quad сумма \quad отклонений \quad S(k) = \Sigma n |kn * xn - yn|
# $

# %% [markdown]
# Наши точки расположены $
# \begin{pmatrix}
# -3 & 2 \\
# 2 & 2 \\
# 5 & -3
# \end{pmatrix} \quad
# S(k) = |-3k-2|+|2k-2|+|5k+3|
# $

# %% [markdown]
# $
# * 1. k=2/-3  S(k) = 0 + 3.33 + 0.33 = 3.66
# * 2. k=1  S(k) = 5 + 0 + 13 = 18
# * 3. k=-3/5  S(k) = 0.2 + 3.2 + 0 = 3.4
#
# Итого функция будет y=-0.6*x
#
# \$

# %% [markdown]
# ![image.png](./geogebra-export.png)

# %% [markdown]
# Задача 5 МНК
# $
# \Delta=(y - kx)^2 \quad \Sigma n = (yn - knxn)^2
# $

# %% [markdown]
# $ Q(k) = (2+3k)^2+(2-2k)^2+(-3-5k)^2 \quad =  \quad (4+12k+9k^2)+(4-8k+4k^2)+(9+30k+25k^2) \quad = \quad 38k^2+34k+17
# $

# %% [markdown]
# $
# (38k^2)\prime = 76k \quad
# (34k)\prime = 34 \quad
# (17)\prime = 0
# $

# %% [markdown]
# $
# 76k+34+0=0 \quad 76k=-34 \quad k=-34/76 \quad k = -0.44
# $

# %% [markdown]
# Задание 6
#
# * Запишите матрично-векторное уравнение $Ax = b$ в виде системы линейных уравнений.
#
# * Решите его любым способом, найдя **вектор** $x$. Решение опишите.
#
#
#
# $$
# A =
#  \begin{pmatrix}
#   1 & 2 & 4 \\
#   2 & 1 & -1 \\
#   1 & -1 & 1 \\
#  \end{pmatrix}
#  $$
#
#  $$
#  b =
#   \begin{pmatrix}
#   3 \\
#   -9 \\
#   0 \\
#  \end{pmatrix}
#  $$

# %% [markdown]
# $
#  \begin{pmatrix}
#  1 & 2 & 4 \\
#  2 & 1 & -1\\
#  1 & -1 & 1
#  \end{pmatrix}
# \cdot
# \begin{pmatrix}
# x1\\
# x2\\
# x3
# \end{pmatrix}
# =
# \begin{pmatrix}
# 3\\
# -9\\
# 0
#  \end{pmatrix}
# $

# %% [markdown]
# $
# \begin{cases} x1+2x2+4x3 = 3 \\ 2x1+x2-x3 = -9 \\ x1-x2+x3=0 \end{cases}
# $

# %% [markdown]
# Метод Гаусса
#
# $
# \begin{pmatrix}
#  1 & 2 & 4 \\
#  2 & 1 & -1\\
#  1 & -1 & 1
# \end{pmatrix}
# \begin{pmatrix}
# 3\\
# -9\\
# 0
# \end{pmatrix}
# =
#  \begin{pmatrix}
#  1 & 2 & 4 \\
#  0 & -3 & -9\\
#  0 & -3 & -3
#  \end{pmatrix}
# \begin{pmatrix}
# 3\\
# -15\\
# -3
#  \end{pmatrix}
# =
#  \begin{pmatrix}
#  1 & 2 & 4 \\
#  0 & -3 & -9\\
#  0 & 0 & 6
#  \end{pmatrix}
# \begin{pmatrix}
# 3\\
# -15\\
# 12
#  \end{pmatrix}
# $

# %% [markdown]
# $
# 6x3=12 \quad x3=2;
# -3x2-9*2 = -15 \quad x2=-1;
# x1-2+8 = 3 \quad x1=2;
# $

# %% [markdown]
# $X=
# \begin{pmatrix}
# -3\\
# -1\\
# 2
# \end{pmatrix}
# $

# %% [markdown]
# Задание 7
#
# На рисунке изображена плотность некоторого непрерывного распределения:
#
# <img src="https://github.com/dmi3eva/resources/blob/main/2026-04-27_PDF.png?raw=true" width="250">
#
# **6-1:** Вычислите вероятность попадания случайной величины в интервал от 0 до 0.5 включительно.
#
# **6-2:** Запишите функцию вероятности (CDF) этого распределения.

# %% [markdown]
# 6-1 для вычисления вероятности непрерывного распределения в интервале необходимо вычислить площадь под фигурой.
# для функции f(x)=2x то будет интеграл
# $
# ∫ f(x) dx = ∫2xdx = x^2  \quad расчет \quad вероятности \quad  P(x) = 0.5^2-0^2 = 0.25
# $

# %% [markdown]
# 6-2
# 1. x<0 : f(x) = 0
# 2. $0\leq x \leq 1$ f(x) = ∫2xdx = x^2
# 3. 1 x>1

# %% [markdown]
# $
# \begin{cases} 0,x<0 \\ x^2, 0\leq x\leq1 \\ 1,x>1 \end{cases}
# $

# %% [markdown]
# Задание 8
#
# На координатной плоскости отмечено 3 точки:
#
# <img src="https://github.com/dmi3eva/resources/blob/main/2026-04-27_OLS-home.png?raw=true" width="500">
#
# подберите прямую из множества всех прямых на плоскости, используя матричное решение метода наименьших квадратов: $w_{min} = (X^TX)^{-1}X^Ty$. .

# %% [markdown]
# Наши координаты
# $
# \begin{pmatrix}
# -3 & 2 \\
# 2 & 2 \\
# 5 & -3
# \end{pmatrix}
# X = \begin{pmatrix}
# -3 & 1 \\
# 2 & 1 \\
# 5 & 1
# \end{pmatrix}
# Y =
# \begin{pmatrix}
# 2 \\
# 2\\
# -3
# \end{pmatrix}
# $

# %% [markdown]
# $ (X^TX)  =
#  \begin{pmatrix}
# -3 & 2 & 5 \\
# 1 & 1 & 1
# \end{pmatrix} \cdot
# \begin{pmatrix}
# -3 & 1 \\
# 2 & 1 \\
# 5 & 1
# \end{pmatrix}=
# \begin{pmatrix}
# -3^2+2^2+5^2 & -3+2+5 \\
# -3+2+5 & 1+1+1
# \end{pmatrix} =
# \begin{pmatrix}
# 38 & 4 \\
# 4 & 3
# \end{pmatrix}
# $

# %% [markdown]
# Для вычисления обратной матрицы вычислим определитель
#
# $
# \begin{pmatrix}
# 38 & 4 \\
# 4 & 3
# \end{pmatrix} = 38 \cdot 3 - 4 \cdot 4 = 114 - 116 = 98
# \quad \Delta = \frac{1}{98} \quad
# $
#
#
# $
# (X^TX)^{-1} = \frac{1}{98} \cdot
# \begin{pmatrix}
# 3 & -4 \\
# -4 & 38
# \end{pmatrix}
# $

# %% [markdown]
# Итого
#
# $w_{min} = (X^TX)^{-1}X^Ty$.
#
# $
# \frac{1}{98} \cdot
# \begin{pmatrix}
# 3 & -4 \\
# -4 & 38
# \end{pmatrix} \cdot
# \begin{pmatrix}
# -17 \\
# 1
# \end{pmatrix} =
# \frac{1}{98} \cdot
# \begin{pmatrix}
# -51-4 \\
# 68+38
# \end{pmatrix} =
# \frac{1}{98} \cdot
# \begin{pmatrix}
# -55 \\
# 106
# \end{pmatrix}
# $
#
# $
# y = -\frac{55}{98}x+\frac{106}{98}
# $
#
# $
# y = -0.56x+1.08
# $
